# %% [markdown]
# # **Team 7 - Introduction**
#
#
# Hi there! We are team 7 from Python for Data Analysts: Methods & Tools class of MBAN Dual Degree. Our team members are, Badr’Eddine Bensaid, Anna Tonello, Mai Takara, Sreekanth Kanna, and Won Seok Hur. We all come from different parts of the world. Badr’Eddine comes from Belgium. He is 26 years old, and his first masters program was MIM. He is seeking to become a marketing manager, and loves to talk about cars, food, and motorcycles! Anna, who comes from Italy also studied MIM for her first degree. She is 25 years old, and seeking to become a marketing strategist. She loves to travel, talk about history, and also cooking! If you want to learn something from marketing, Anna and Badr'Eddine are our specialists, and will be happy to help you out!
# Sreekanth, Mai, and Won studied MIB for their first masters program like many others from our class. Sreekanth comes from India and is seeking to become a business analyst. He is 24 years old, and loves hiking, traveling, and plane spotting!! Mai is 25 years old, and she comes from Japan. She is seeking to become a marketing analyst, and loves photography, movies, and especially dogs! If you are a dog lover, you know where to come. Lastly, our teammate Won comes from South Korea. He is 29 years old, and seeking to become a data analyst. He loves to talk about wines, golf, and video games!
# Our teammates are interested in various things, and would be happy to talk about it with you!! So if you find something in common, come visit us!

# %%
#Team assignment. Team 7

#We are going to present our team to the rest of the class. 

# This code is a simple script that greets the user, asks them to choose a country 
# From a predefined list, and then prints a fun fact about that country. 
# The script also asks the user to choose a previous program and prints a statement about that program.

# Prints a separator line
print(f"""
{'-' * 40}

{'-' * 40}\n""")

# Asks user to press Enter to continue
input("Press < Enter > to continue.")

# Prints another separator line
print(f"""
{'-' * 40}

{'-' * 40}\n""")

# Define the list of countries of origin of the team
country_lst = ["Belgium", "Italy", "Japan", "India", "South Korea"]

# Asks the user to choose a country from the predefined list
#Select letters instead of the country to make it more user firendly and leave smaller error margin
choose_country = input(prompt = """Choose a country among 
A. Belgium 
B. Italy 
C. Japan 
D. India 
E. South Korea\n""")

#In order to not have a letter in between the final story we defined a new variable 'country' so the country is printed in the story
if choose_country == 'A' or choose_country == 'a':
    country='Belgium'

elif choose_country == 'B' or choose_country == 'b':
    country='Italy'

elif choose_country == 'C' or choose_country == 'c':
    country='Japan'

elif choose_country == 'D' or choose_country == 'd':
    country='India'

elif choose_country == 'E' or choose_country == 'e':
    country='South Korea'

else:
    print()
    
# Asks the user to choose previous program
previous_program = input(prompt = "Choose previous program among MIM and MIB:\n")

# Asks the user to tell us what they are interested in
interests_1 = input(prompt = "Tell us what you are interested in:\n")

# Asks the user to choose a team member
team_member = input(prompt = """Who do you want to know about? 
A. Badr 
B. Anna 
C. Mai 
D. Sreekanth 
E. Won\n""")

#In order to not have a letter in between the final story we defined a new variable 'member' so the tem member is printed in the story
if team_member == 'A' or choose_country == 'a':
    member='Badr'

elif team_member == 'B' or choose_country == 'b':
    member='Anna'

elif team_member == 'C' or choose_country == 'c':
    member='Mai'

elif team_member == 'D' or choose_country == 'd':
    member='Sreekanth'

elif team_member == 'E' or choose_country == 'e':
    member='Won'

else:
     print()

# Define a list of lists to store information about the team members
member_lst = [
                ["Badr", "cars, food, photography and motorcycles"],
                ["Anna", "travelling, history and cooking"],
                ["Mai", "movies, dogs, and photography"],
                ["Sreekanth", "plane spotting, travelling and hiking"],
                ["Won", "wines, golf, and video games"]
]


# Prints a greeting and information about the team
print(f"""
\f

Hi there!  We are team 7. We are Badr’Eddine Bensaid , Anna Tonello, Mai Takara, Sreekanth Kanna, Won Seok Hur.  
We’re in the hard and funny journey of Python for Data Analysts: Methods & Tools of DDMBAN.
We are a very diverse team in fact we are from {country_lst[0]},{country_lst[1]},{country_lst[2]},{country_lst[3]}, and {country_lst[4]}. 
Do you want to hear a fun fact about {country} ?

""")

# Using if-else statement to choose the fun fact about the chosen country
if choose_country == 'A' or  choose_country == 'a':
    print("""Badr is from there. Did you know that despite fries were invented in Belgium they world call them french fires? Isn\'t it annoyng?""")

elif choose_country == 'B' or  choose_country == 'b':
    print("""Anna is from there. Did you know that if you toss a coin into the Trevi fountain you\'ll return to Rome. 
And people really want to return to Rome as tourists toss around €3,000 a day into the fountain""")

elif choose_country == 'C' or  choose_country == 'c':
    print("""Mai is from there and she says that there is 1 vending machine for every 24 people in Japan, which is no.1 in the world in terms of population ratio.""")
    
elif choose_country == 'D' or  choose_country == 'd':
    print("""Sreekanth is from there. Did you know that India has 29 states and 22 official languages with more than 121 languages spoken in the country. 
Going from one state to other state in India is like Country hopping because the language and the culture in the other state changes.""")
    
elif choose_country == 'E' or  choose_country == 'e':
    print("""Won is from there. Did you know that Koreans are considered one of the top drinkers in Asia by far. 
South Korea has a strong drinking culture compared to its neighboring countries in Asia.""")   

else:
    print("""Sorry nobody from this country is here""")
    

    
# Using if-else statement to print a comment whether the use choose MIM or MIB.
print(f"""
\f    
Wasn't it interesting? Now, let us introduce our backgrounds. 
Two MIM’s and three MIB’s at your service! For those who did {previous_program}, 
""")

if previous_program == "MIM" or previous_program == "mim":
    print("Marketing is the best! Do you agree? Well Anna and Badr’Eddine had a lot of fun last year especially during customer journey.")
elif previous_program == "MIB" or previous_program == "mib":
    print("International Business is amazing! Sreekanth, Mai, and Won had such a great time during their previous masters!")
else:
    print("sorry, there's no people from that program in our team. However, congratulations on completeing it!!")


print(f"""
\f
Our teammates are interested in various things, and would be happy to talk about it with you!! What are you interested in?
WOW, {interests_1}! That is amazing!! We would like to hear more about that! Now let's see if you have something in common with {member}.
""")


#Combined list if-else statement to bring the team member and interests to the story
if team_member == 'A' or  team_member == 'a':
    print(member_lst[0][0] + " loves to talk about " + member_lst[0][1] + " ! ")

elif team_member == 'B' or  team_member == 'b':
    print(member_lst[1][0] + " loves to talk about " + member_lst[1][1] + " ! ")

elif team_member == 'C' or  team_member == 'c':
    print(member_lst[2][0] + " loves to talk about " + member_lst[2][1] + " ! ")

elif team_member == 'D' or  team_member == 'd':
    print(member_lst[3][0] + " loves to talk about " + member_lst[3][1] + " ! ")

elif team_member == 'E' or  team_member == 'e':
    print(member_lst[4][0] + " loves to talk about " + member_lst[4][1] + " ! ")

else:
    print("Sorry, we don't have a member by that name.")

    
# The end. The team thanks the user 
print(f"""
\f
Thank you so much for taking time to know about us! 
See you soon!
""")
# Out:
# ----------------------------------------
#
# ----------------------------------------
#
# Press < Enter > to continue.
#
# ----------------------------------------
#
# ----------------------------------------
#
# Choose a country among
# A. Belgium
# B. Italy
# C. Japan
# D. India
# E. South Korea
# C
# Choose previous program among MIM and MIB:
# MIM
# Tell us what you are interested in:
# COFFEE
# Who do you want to know about?
# A. Badr
# B. Anna
# C. Mai
# D. Sreekanth
# E. Won
# E
#
#
#
# Hi there!  We are team 7. We are Badr’Eddine Bensaid , Anna Tonello, Mai Takara, Sreekanth Kanna, Won Seok Hur.
# We’re in the hard and funny journey of Python for Data Analysts: Methods & Tools of DDMBAN.
# We are a very diverse team in fact we are from Belgium,Italy,Japan,India, and South Korea.
# Do you want to hear a fun fact about Japan ?
#
#
# ...
